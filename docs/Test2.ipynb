# %% [markdown]
# Test2
# =====

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot

# %%
plt.plot(1, 1, "ko")
plt.show()

# %% [markdown]
# ## Final

# %%
plt.hist([1, 2, 3])
plt.show()
